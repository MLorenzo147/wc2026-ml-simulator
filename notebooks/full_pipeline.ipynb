# %% [markdown]
# # Full Pipeline (Narratif)
#
# Ce notebook est un guide end-to-end. Il se contente d appeler les scripts et de verifier les sorties.

# %%
from pathlib import Path
import subprocess

def run(cmd):
    print("Running:", " ".join(cmd))
    subprocess.run(cmd, check=False)

if Path("Makefile").exists():
    run(["make", "help"])
else:
    print("Makefile missing")

# %%
# Step 1: build dataset
# run(["make", "build-dataset"])

# Step 2: train models
# run(["make", "train"])

# Step 3: evaluate
# run(["make", "evaluate"])

# Step 4: simulate
# run(["make", "simulate"])

# %%
import json
from pathlib import Path

OUTPUT_DIR = Path("outputs")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

run_plan = {
    "step_1": "make build-dataset",
    "step_2": "make train",
    "step_3": "make evaluate",
    "step_4": "make simulate"
}
(OUTPUT_DIR / "run_plan.json").write_text(json.dumps(run_plan, indent=2))
